# %%
# %sql
create database project4cat.project4db;

# %%
# %sql
CREATE VOLUME project4cat.project4db.p4raw;

# %%
# %sql
create volume project4cat.project4db.p4bronze;

# %%
# %sql
create volume project4cat.project4db.p4silver;

# %%
# %sql
create volume project4cat.project4db.p4gold;
